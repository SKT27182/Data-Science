# %% [markdown]
# ### Removing whitespace

# %%
from files.files import remove_spaces
remove_spaces()
# Out:
# 01-Capstone-Project-Solutions.ipynb
# 01-Capstone-Project-Solutions-checkpoint.ipynb
# 00-Capstone-Project-checkpoint
# 01-KNN-Exercise.ipynb
# 01-KNN-Exercise-checkpoint.ipynb
# 02-Text-Classification-Assessment.ipynb
# 02-Text-Classification-Assessment-checkpoint.ipynb
# 04-Linear-Regression-Project-DataSet.ipynb
# 04-Linear-Regression-Project-DataSet-checkpoint.ipynb
# 00-Sup-Learning-Capstone-Tree-Methods.ipynb
# 00-Sup-Learning-Capstone-Tree-Methods-checkpoint.ipynb
# 11-Pandas-Project-Exercise.ipynb
# 11-Pandas-Project-Exercise-checkpoint.ipynb
# 01-PythonCrashCourse.ipynb
# 02-PythonCrashCourseExercises.ipynb
# 03-PythonCrashCourseExercises-Solutions.ipynb
# 01-PythonCrashCourse-checkpoint.ipynb
# 02-PythonCrashCourseExercises-checkpoint.ipynb
# 04-MatplotlibExercises.ipynb
# 05-MatplotlibExercises-Solutions.ipynb
# 04-MatplotlibExercises-checkpoint.ipynb
# 05-MatplotlibExercises-Solutions-checkpoint.ipynb
# 02-Logistic-Regression-Project-Exercise.ipynb
# 02-Logistic-Regression-Project-Exercise-checkpoint.ipynb

# %% [markdown]
# ### Removing the logo

# %%
texts_to_remove = [

    '''"___\\n",''',

    '../Pierian_Data_Logo.png',
    'http://www.pieriandata.com',
    'www.pieriandata.com',
    'For more information, visit us at',
    'Copyright Pierian Data',
    'https://www.udemy.com/user/joseportilla/',
    'Copyright by Pierian Data Inc.'
]

# %%
import os
for root, _ , files in os.walk('.'):
    for file in files:
        if file.endswith('.ipynb'):
            with open(os.path.join(root, file), 'r') as f:
                text = f.read()
                for keys in texts_to_remove:
                    text = text.replace(keys, '')
                with open(os.path.join(root, file), 'w') as f:
                    f.write(text)

# %% [markdown]
# ### Converting the notebooks to HTML

# %%
from html_setup.notebook import Notebook
import os
f = Notebook('.')

# %%
outputs = []
for folder, _, files in os.walk('.'):
    for file in files:
        if file.endswith('.ipynb'):
            file_path = os.path.join(folder, file)
            if ".ipynb_checkpoints" in file_path:
                continue
            if "__pycache__" in file_path:
                continue
            
            print(f"Converting {file}")
            try:
                output = f.export_notebook(file_path)
                outputs.append(output)
            except Exception as e:
                print(f"Error converting {file}")
                print(e)
# Out:
# Converting Organize_Notebooks.ipynb
# Converting 00-Capstone-Project.ipynb
# Converting 01-Capstone-Project-Solutions.ipynb
# Converting 02-Linear-Regression-Project-Exercise.ipynb
# Converting 01-Grid-Search.ipynb
# Converting 03-Linear-Regression-Project-Exercise-Solutions.ipynb
# Converting 00-Cross-Validation.ipynb
# Converting 00-KNN-Classification.ipynb
# Converting 01-KNN-Exercise.ipynb
# Converting 02-KNN-Exercise-Solutions.ipynb
# Converting 00-Hierarchical-Clustering.ipynb
# Converting 03-Text-Classification-Assessment-Solution.ipynb
# Converting 00-Feature-Extraction-From-Text.ipynb
# Converting 01-Text-Classification.ipynb
# Converting 02-Text-Classification-Assessment.ipynb
# Converting 00-PCA-Manual-Implementation.ipynb
# Converting 03-PCA-Exercise-Project-Solutions.ipynb
# Converting 01-PCA-Scikit-Learn.ipynb
# Converting 02-PCA-Exercise-Project.ipynb
# Converting 02-SVM-Project-Exercise.ipynb
# Converting 01-SVM-Regression.ipynb
# Converting 03-SVM-Project-Exercise-Solutions.ipynb
# Converting 00-SVM-Classification.ipynb
# Converting 01-Linear-Regression-with-Scitkit-Learn.ipynb
# Converting 02-Polynomial-Regression.ipynb
# Converting 00-Intro-to-Simple-Linear-Regression.ipynb
# Converting 04-Linear-Regression-Project-DataSet.ipynb
# Converting 03-Regularization-Ridge-Lasso-ElasticNet.ipynb
# Converting 01-Dealing-with-Missing-Data.ipynb
# Converting 02-Dealing-with-Categorical-Data.ipynb
# Converting 00-Dealing-with-Outliers.ipynb
# Converting 00-Decision-Trees.ipynb
# Converting 00-AdaBoost.ipynb
# Converting 01-Gradient-Boosting.ipynb
# Converting 00-Hierarchal-Clustering-Example.ipynb
# Converting 01-NumPy-Indexing-and-Selection.ipynb
# Converting 00-NumPy-Arrays.ipynb
# Converting 03-NumPy-Exercises.ipynb
# Converting 04-NumPy-Exercises-Solutions.ipynb
# Converting 02-NumPy-Operations.ipynb
# Converting 01-Sup-Learning-Capstone-Tree-Methods-SOLNs.ipynb
# Converting 00-Sup-Learning-Capstone-Tree-Methods-Exercise.ipynb
# Converting 02-DBSCAN-Project-Exercise.ipynb
# Converting 01-DBSCAN-Hyperparameters.ipynb
# Converting 03-DBSCAN-Project-Solutions.ipynb
# Converting 00-DBSCAN.ipynb
# Converting 01-DataFrames.ipynb
# Converting 08-Time-Methods.ipynb
# Converting 00-Series.ipynb
# Converting 04-Missing-Data.ipynb
# Converting 06-Combining-DataFrames.ipynb
# Converting 09-Inputs-and-Outputs.ipynb
# Converting 07-Text-Methods.ipynb
# Converting 10-Pivot-Tables.ipynb
# Converting 02-Conditional-Filtering.ipynb
# Converting 03-Useful-Methods.ipynb
# Converting 12-Pandas-Project-Exercise-Solution.ipynb
# Converting 05-Groupby-Operations-and-MultiIndex.ipynb
# Converting 11-Pandas-Project-Exercise.ipynb
# Converting 03-Python-Crash-Course-Exercises-Solutions.ipynb
# Converting 02-Python-Crash-Course-Exercises.ipynb
# Converting 01-Python-Crash-Course.ipynb
# Converting 01-Kmeans-Color-Quantization.ipynb
# Converting 02-Kmeans-Clustering-Project-Exercise.ipynb
# Converting 00-Kmeans-Clustering.ipynb
# Converting 03-Kmeans-Clustering-Project-Solutions.ipynb
# Converting 01-Random-Forest-Regression.ipynb
# Converting 00-Random-Forest-Classification.ipynb
# Converting 03-Matplotlib-Styling-Plots.ipynb
# Converting 06-Additional-Matplotlib-Commands-NO_VIDEO.ipynb
# Converting 02-Matplotlib-SubPlots.ipynb
# Converting 04-Matplotlib-Exercises.ipynb
# Converting 00-Matplotlib-Basics.ipynb
# Converting 05-Matplotlib-Exercises-Solutions.ipynb
# Converting 01-Matplotlib-Figures.ipynb
# Converting 03-Logistic-Regression-Project-Exercise-Solution.ipynb
# Converting 00-Logistic-Regression.ipynb
# Converting 02-Logistic-Regression-Project-Exercise.ipynb
# Converting 01-Multi-Class-Logistic-Regression.ipynb
# Converting 02-Categorical-Plots-Stat-Estimation.ipynb
# Converting 03-Categorical-Plots-Distributions.ipynb
# Converting 06-Matrix-Plots.ipynb
# Converting 05-Seaborn-Grids.ipynb
# Converting 08-Seaborn-Exercise-Solutions.ipynb
# Converting 07-Seaborn-Exercise.ipynb
# Converting 01-Distribution-Plots.ipynb
# Converting 04-Comparison-Plots.ipynb
# Converting 00-Scatter-Plots.ipynb
# Converting 01-Serving-Model-as-API.ipynb
# Converting 00-Model-Persistence.ipynb

# %% [markdown]
# ### Adding them to index.html

# %%
outputs = sorted(outputs)[:-1]  # not including the organizing html file

# %%
'./24-Model-Deployment/01-Serving-Model-as-API.html'.split('/')[-2]
# Out:
# '24-Model-Deployment'

# %%
title = "01-Serving-Model-as-API.html"
" ".join(title.split("-")[1:])
# Out:
# 'Serving Model as API.html'

# %%
def current_dir(path):
    return ' '.join(path.split('/')[-2].split('-')[1:])

# %%
current_dir('./24-Model-Deployment/01-Serving-Model-as-API.html')
# Out:
# 'Model Deployment'

# %%
string = ''
present_dir = 'Python Crash Course'

container = """<div>{heading}
{content}
</div>
"""

txt = """
<li>
    <a href="Machine_Learning_and_Data-Science_by_Jose_Portilla/{final_path}" target = 'blank' class = 'links'>{title}</a>
</li>
"""

container_ = ''

for file_path in outputs:
    final_path = file_path  #'/'.join(file_path.split("\\")[1:])
    if ".ipynb_checkpoints" in final_path:
        continue
    elif "__pycache__" in file_path:
        continue
    elif ('Exercise.html' in file_path) or ('Exercises.html' in file_path) or ('Project.html' in file_path) or ('Assessment.html' in file_path):
        continue
    else:
        title = final_path.split("/")[-1]
        title = " ".join(title.split("-")[1:])
        title = title.split(".")[0]
        if present_dir == current_dir(final_path):
            txt_ = txt.format(final_path=final_path, title=title)
            string += txt_
            #print(string)
        else:
            container_ += container.format(heading=present_dir,content=string)
            string = ''
            txt_ = txt.format(final_path=final_path, title=title)
            string += txt_
            present_dir = current_dir(final_path)

container_ += container.format(heading=present_dir,content=string)

print(container_)
# Out:
# <div>Python Crash Course
#
# <li>
#     <a href="Machine_Learning_and_Data-Science_by_Jose_Portilla/./01-Python-Crash-Course/01-Python-Crash-Course.html" target = 'blank' class = 'links'>Python Crash Course</a>
# </li>
#
# <li>
#     <a href="Machine_Learning_and_Data-Science_by_Jose_Portilla/./01-Python-Crash-Course/03-Python-Crash-Course-Exercises-Solutions.html" target = 'blank' class = 'links'>Python Crash Course Exercises Solutions</a>
# </li>
#
# </div>
# <div>Numpy
#
# <li>
#     <a href="Machine_Learning_and_Data-Science_by_Jose_Portilla/./02-Numpy/00-NumPy-Arrays.html" target = 'blank' class = 'links'>NumPy Arrays</a>
# </li>
#
# <li>
#     <a href="Machine_Learning_and_Data-Science_by_Jose_Portilla/./02-Numpy/01-NumPy-Indexing-and-Selection.html" target = 'blank' class = 'links'>NumPy Indexing and Selection</a>
# </li>
#
# <li>
#     <a href="Machine_Learning_and_Data-Science_by_Jose_Portilla/./02-Numpy/02-NumPy-Operations.html" target = 'blank' class = 'links'>NumPy Operations</a>
# </li>
#
# <li>
#     <a href="Machine_Learning_and_Data-Science_by_Jose_Portilla/./02-Numpy/04-NumPy-Exercises-Solutions.html" target = 'blank' class = 'links'>NumPy Exercises Solutions</a>
# </li>
#
# </div>
# <div>Pandas
#
# <li>
#     <a href="Machine_Learning_and_Data-Science_by_Jose_Portilla/./03-Pandas/00-Series.html" target = 'blank' class = 'links'>Series</a>
# </li>
#
# <li>
#     <a href="Machine_Learning_and_Data-Science_by_Jose_Portilla/./03-Pandas/01-DataFrames.html" target = 'blank' class = 'links'>DataFrames</a>
# </li>
#
# <li>
#     <a href="Machine_Learning_and_Data-Science_by_Jose_Portilla/./03-Pandas/02-Conditional-Filtering.html" target = 'blank' class = 'links'>Conditional Filtering</a>
# </li>
#
# <li>
#     <a href="Machine_Learning_and_Data-Science_by_Jose_Portilla/./03-Pandas/03-Useful-Methods.html" target = 'blank' class = 'links'>Useful Methods</a>
# </li>
#
# <li>
#     <a href="Machine_Learning_and_Data-Science_by_Jose_Portilla/./03-Pandas/04-Missing-Data.html" target = 'blank' class = 'links'>Missing Data</a>
# </li>
#
# <li>
#     <a href="Machine_Learning_and_Data-Science_by_Jose_Portilla/./03-Pandas/05-Groupby-Operations-and-MultiIndex.html" target = 'blank' class = 'links'>Groupby Operations and MultiIndex</a>
# </li>
#
# <li>
#     <a href="Machine_Learning_and_Data-Science_by_Jose_Portilla/./03-Pandas/06-Combining-DataFrames.html" target = 'blank' class = 'links'>Combining DataFrames</a>
# </li>
#
# <li>
#     <a href="Machine_Learning_and_Data-Science_by_Jose_Portilla/./03-Pandas/07-Text-Methods.html" target = 'blank' class = 'links'>Text Methods</a>
# </li>
#
# <li>
#     <a href="Machine_Learning_and_Data-Science_by_Jose_Portilla/./03-Pandas/08-Time-Methods.html" target = 'blank' class = 'links'>Time Methods</a>
# </li>
#
# <li>
#     <a href="Machine_Learning_and_Data-Science_by_Jose_Portilla/./03-Pandas/09-Inputs-and-Outputs.html" target = 'blank' class = 'links'>Inputs and Outputs</a>
# </li>
#
# <li>
#     <a href="Machine_Learning_and_Data-Science_by_Jose_Portilla/./03-Pandas/10-Pivot-Tables.html" target = 'blank' class = 'links'>Pivot Tables</a>
# </li>
#
# <li>
#     <a href="Machine_Learning_and_Data-Science_by_Jose_Portilla/./03-Pandas/12-Pandas-Project-Exercise-Solution.html" target = 'blank' class = 'links'>Pandas Project Exercise Solution</a>
# </li>
#
# </div>
# <div>Matplotlib
#
# <li>
#     <a href="Machine_Learning_and_Data-Science_by_Jose_Portilla/./04-Matplotlib/00-Matplotlib-Basics.html" target = 'blank' class = 'links'>Matplotlib Basics</a>
# </li>
#
# <li>
#     <a href="Machine_Learning_and_Data-Science_by_Jose_Portilla/./04-Matplotlib/01-Matplotlib-Figures.html" target = 'blank' class = 'links'>Matplotlib Figures</a>
# </li>
#
# <li>
#     <a href="Machine_Learning_and_Data-Science_by_Jose_Portilla/./04-Matplotlib/02-Matplotlib-SubPlots.html" target = 'blank' class = 'links'>Matplotlib SubPlots</a>
# </li>
#
# <li>
#     <a href="Machine_Learning_and_Data-Science_by_Jose_Portilla/./04-Matplotlib/03-Matplotlib-Styling-Plots.html" target = 'blank' class = 'links'>Matplotlib Styling Plots</a>
# </li>
#
# <li>
#     <a href="Machine_Learning_and_Data-Science_by_Jose_Portilla/./04-Matplotlib/05-Matplotlib-Exercises-Solutions.html" target = 'blank' class = 'links'>Matplotlib Exercises Solutions</a>
# </li>
#
# <li>
#     <a href="Machine_Learning_and_Data-Science_by_Jose_Portilla/./04-Matplotlib/06-Additional-Matplotlib-Commands-NO_VIDEO.html" target = 'blank' class = 'links'>Additional Matplotlib Commands NO_VIDEO</a>
# </li>
#
# </div>
# <div>Seaborn
#
# <li>
#     <a href="Machine_Learning_and_Data-Science_by_Jose_Portilla/./05-Seaborn/00-Scatter-Plots.html" target = 'blank' class = 'links'>Scatter Plots</a>
# </li>
#
# <li>
#     <a href="Machine_Learning_and_Data-Science_by_Jose_Portilla/./05-Seaborn/01-Distribution-Plots.html" target = 'blank' class = 'links'>Distribution Plots</a>
# </li>
#
# <li>
#     <a href="Machine_Learning_and_Data-Science_by_Jose_Portilla/./05-Seaborn/02-Categorical-Plots-Stat-Estimation.html" target = 'blank' class = 'links'>Categorical Plots Stat Estimation</a>
# </li>
#
# <li>
#     <a href="Machine_Learning_and_Data-Science_by_Jose_Portilla/./05-Seaborn/03-Categorical-Plots-Distributions.html" target = 'blank' class = 'links'>Categorical Plots Distributions</a>
# </li>
#
# <li>
#     <a href="Machine_Learning_and_Data-Science_by_Jose_Portilla/./05-Seaborn/04-Comparison-Plots.html" target = 'blank' class = 'links'>Comparison Plots</a>
# </li>
#
# <li>
#     <a href="Machine_Learning_and_Data-Science_by_Jose_Portilla/./05-Seaborn/05-Seaborn-Grids.html" target = 'blank' class = 'links'>Seaborn Grids</a>
# </li>
#
# <li>
#     <a href="Machine_Learning_and_Data-Science_by_Jose_Portilla/./05-Seaborn/06-Matrix-Plots.html" target = 'blank' class = 'links'>Matrix Plots</a>
# </li>
#
# <li>
#     <a href="Machine_Learning_and_Data-Science_by_Jose_Portilla/./05-Seaborn/08-Seaborn-Exercise-Solutions.html" target = 'blank' class = 'links'>Seaborn Exercise Solutions</a>
# </li>
#
# </div>
# <div>Capstone Project
#
# <li>
#     <a href="Machine_Learning_and_Data-Science_by_Jose_Portilla/./06-Capstone-Project/01-Capstone-Project-Solutions.html" target = 'blank' class = 'links'>Capstone Project Solutions</a>
# </li>
#
# </div>
# <div>Linear Regression Models
#
# <li>
#     <a href="Machine_Learning_and_Data-Science_by_Jose_Portilla/./08-Linear-Regression-Models/00-Intro-to-Simple-Linear-Regression.html" target = 'blank' class = 'links'>Intro to Simple Linear Regression</a>
# </li>
#
# <li>
#     <a href="Machine_Learning_and_Data-Science_by_Jose_Portilla/./08-Linear-Regression-Models/01-Linear-Regression-with-Scitkit-Learn.html" target = 'blank' class = 'links'>Linear Regression with Scitkit Learn</a>
# </li>
#
# <li>
#     <a href="Machine_Learning_and_Data-Science_by_Jose_Portilla/./08-Linear-Regression-Models/02-Polynomial-Regression.html" target = 'blank' class = 'links'>Polynomial Regression</a>
# </li>
#
# <li>
#     <a href="Machine_Learning_and_Data-Science_by_Jose_Portilla/./08-Linear-Regression-Models/03-Regularization-Ridge-Lasso-ElasticNet.html" target = 'blank' class = 'links'>Regularization Ridge Lasso ElasticNet</a>
# </li>
#
# <li>
#     <a href="Machine_Learning_and_Data-Science_by_Jose_Portilla/./08-Linear-Regression-Models/04-Linear-Regression-Project-DataSet.html" target = 'blank' class = 'links'>Linear Regression Project DataSet</a>
# </li>
#
# </div>
# <div>Feature Engineering
#
# <li>
#     <a href="Machine_Learning_and_Data-Science_by_Jose_Portilla/./09-Feature-Engineering/00-Dealing-with-Outliers.html" target = 'blank' class = 'links'>Dealing with Outliers</a>
# </li>
#
# <li>
#     <a href="Machine_Learning_and_Data-Science_by_Jose_Portilla/./09-Feature-Engineering/01-Dealing-with-Missing-Data.html" target = 'blank' class = 'links'>Dealing with Missing Data</a>
# </li>
#
# <li>
#     <a href="Machine_Learning_and_Data-Science_by_Jose_Portilla/./09-Feature-Engineering/02-Dealing-with-Categorical-Data.html" target = 'blank' class = 'links'>Dealing with Categorical Data</a>
# </li>
#
# </div>
# <div>Cross Val and LinReg Project
#
# <li>
#     <a href="Machine_Learning_and_Data-Science_by_Jose_Portilla/./10-Cross-Val-and-LinReg-Project/00-Cross-Validation.html" target = 'blank' class = 'links'>Cross Validation</a>
# </li>
#
# <li>
#     <a href="Machine_Learning_and_Data-Science_by_Jose_Portilla/./10-Cross-Val-and-LinReg-Project/01-Grid-Search.html" target = 'blank' class = 'links'>Grid Search</a>
# </li>
#
# <li>
#     <a href="Machine_Learning_and_Data-Science_by_Jose_Portilla/./10-Cross-Val-and-LinReg-Project/03-Linear-Regression-Project-Exercise-Solutions.html" target = 'blank' class = 'links'>Linear Regression Project Exercise Solutions</a>
# </li>
#
# </div>
# <div>Logistic Regression Models
#
# <li>
#     <a href="Machine_Learning_and_Data-Science_by_Jose_Portilla/./11-Logistic-Regression-Models/00-Logistic-Regression.html" target = 'blank' class = 'links'>Logistic Regression</a>
# </li>
#
# <li>
#     <a href="Machine_Learning_and_Data-Science_by_Jose_Portilla/./11-Logistic-Regression-Models/01-Multi-Class-Logistic-Regression.html" target = 'blank' class = 'links'>Multi Class Logistic Regression</a>
# </li>
#
# <li>
#     <a href="Machine_Learning_and_Data-Science_by_Jose_Portilla/./11-Logistic-Regression-Models/03-Logistic-Regression-Project-Exercise-Solution.html" target = 'blank' class = 'links'>Logistic Regression Project Exercise Solution</a>
# </li>
#
# </div>
# <div>K Nearest Neighbors
#
# <li>
#     <a href="Machine_Learning_and_Data-Science_by_Jose_Portilla/./12-K-Nearest-Neighbors/00-KNN-Classification.html" target = 'blank' class = 'links'>KNN Classification</a>
# </li>
#
# <li>
#     <a href="Machine_Learning_and_Data-Science_by_Jose_Portilla/./12-K-Nearest-Neighbors/02-KNN-Exercise-Solutions.html" target = 'blank' class = 'links'>KNN Exercise Solutions</a>
# </li>
#
# </div>
# <div>Support Vector Machines
#
# <li>
#     <a href="Machine_Learning_and_Data-Science_by_Jose_Portilla/./13-Support-Vector-Machines/00-SVM-Classification.html" target = 'blank' class = 'links'>SVM Classification</a>
# </li>
#
# <li>
#     <a href="Machine_Learning_and_Data-Science_by_Jose_Portilla/./13-Support-Vector-Machines/01-SVM-Regression.html" target = 'blank' class = 'links'>SVM Regression</a>
# </li>
#
# <li>
#     <a href="Machine_Learning_and_Data-Science_by_Jose_Portilla/./13-Support-Vector-Machines/03-SVM-Project-Exercise-Solutions.html" target = 'blank' class = 'links'>SVM Project Exercise Solutions</a>
# </li>
#
# </div>
# <div>Decision Trees
#
# <li>
#     <a href="Machine_Learning_and_Data-Science_by_Jose_Portilla/./14-Decision-Trees/00-Decision-Trees.html" target = 'blank' class = 'links'>Decision Trees</a>
# </li>
#
# </div>
# <div>Random Forests
#
# <li>
#     <a href="Machine_Learning_and_Data-Science_by_Jose_Portilla/./15-Random-Forests/00-Random-Forest-Classification.html" target = 'blank' class = 'links'>Random Forest Classification</a>
# </li>
#
# <li>
#     <a href="Machine_Learning_and_Data-Science_by_Jose_Portilla/./15-Random-Forests/01-Random-Forest-Regression.html" target = 'blank' class = 'links'>Random Forest Regression</a>
# </li>
#
# </div>
# <div>Boosted Trees
#
# <li>
#     <a href="Machine_Learning_and_Data-Science_by_Jose_Portilla/./16-Boosted-Trees/00-AdaBoost.html" target = 'blank' class = 'links'>AdaBoost</a>
# </li>
#
# <li>
#     <a href="Machine_Learning_and_Data-Science_by_Jose_Portilla/./16-Boosted-Trees/01-Gradient-Boosting.html" target = 'blank' class = 'links'>Gradient Boosting</a>
# </li>
#
# </div>
# <div>Supervised Learning Capstone Project
#
# <li>
#     <a href="Machine_Learning_and_Data-Science_by_Jose_Portilla/./17-Supervised-Learning-Capstone-Project/01-Sup-Learning-Capstone-Tree-Methods-SOLNs.html" target = 'blank' class = 'links'>Sup Learning Capstone Tree Methods SOLNs</a>
# </li>
#
# </div>
# <div>Naive Bayes and NLP
#
# <li>
#     <a href="Machine_Learning_and_Data-Science_by_Jose_Portilla/./18-Naive-Bayes-and-NLP/00-Feature-Extraction-From-Text.html" target = 'blank' class = 'links'>Feature Extraction From Text</a>
# </li>
#
# <li>
#     <a href="Machine_Learning_and_Data-Science_by_Jose_Portilla/./18-Naive-Bayes-and-NLP/01-Text-Classification.html" target = 'blank' class = 'links'>Text Classification</a>
# </li>
#
# <li>
#     <a href="Machine_Learning_and_Data-Science_by_Jose_Portilla/./18-Naive-Bayes-and-NLP/03-Text-Classification-Assessment-Solution.html" target = 'blank' class = 'links'>Text Classification Assessment Solution</a>
# </li>
#
# </div>
# <div>Kmeans Clustering
#
# <li>
#     <a href="Machine_Learning_and_Data-Science_by_Jose_Portilla/./20-Kmeans-Clustering/00-Kmeans-Clustering.html" target = 'blank' class = 'links'>Kmeans Clustering</a>
# </li>
#
# <li>
#     <a href="Machine_Learning_and_Data-Science_by_Jose_Portilla/./20-Kmeans-Clustering/01-Kmeans-Color-Quantization.html" target = 'blank' class = 'links'>Kmeans Color Quantization</a>
# </li>
#
# <li>
#     <a href="Machine_Learning_and_Data-Science_by_Jose_Portilla/./20-Kmeans-Clustering/03-Kmeans-Clustering-Project-Solutions.html" target = 'blank' class = 'links'>Kmeans Clustering Project Solutions</a>
# </li>
#
# </div>
# <div>Hierarchal Clustering
#
# <li>
#     <a href="Machine_Learning_and_Data-Science_by_Jose_Portilla/./21-Hierarchal-Clustering/00-Hierarchal-Clustering-Example.html" target = 'blank' class = 'links'>Hierarchal Clustering Example</a>
# </li>
#
# </div>
# <div>Hierarchical Clustering
#
# <li>
#     <a href="Machine_Learning_and_Data-Science_by_Jose_Portilla/./21-Hierarchical-Clustering/00-Hierarchical-Clustering.html" target = 'blank' class = 'links'>Hierarchical Clustering</a>
# </li>
#
# </div>
# <div>DBSCAN
#
# <li>
#     <a href="Machine_Learning_and_Data-Science_by_Jose_Portilla/./22-DBSCAN/00-DBSCAN.html" target = 'blank' class = 'links'>DBSCAN</a>
# </li>
#
# <li>
#     <a href="Machine_Learning_and_Data-Science_by_Jose_Portilla/./22-DBSCAN/01-DBSCAN-Hyperparameters.html" target = 'blank' class = 'links'>DBSCAN Hyperparameters</a>
# </li>
#
# <li>
#     <a href="Machine_Learning_and_Data-Science_by_Jose_Portilla/./22-DBSCAN/03-DBSCAN-Project-Solutions.html" target = 'blank' class = 'links'>DBSCAN Project Solutions</a>
# </li>
#
# </div>
# <div>PCA Principal Component Analysis
#
# <li>
#     <a href="Machine_Learning_and_Data-Science_by_Jose_Portilla/./23-PCA-Principal-Component-Analysis/00-PCA-Manual-Implementation.html" target = 'blank' class = 'links'>PCA Manual Implementation</a>
# </li>
#
# <li>
#     <a href="Machine_Learning_and_Data-Science_by_Jose_Portilla/./23-PCA-Principal-Component-Analysis/01-PCA-Scikit-Learn.html" target = 'blank' class = 'links'>PCA Scikit Learn</a>
# </li>
#
# <li>
#     <a href="Machine_Learning_and_Data-Science_by_Jose_Portilla/./23-PCA-Principal-Component-Analysis/03-PCA-Exercise-Project-Solutions.html" target = 'blank' class = 'links'>PCA Exercise Project Solutions</a>
# </li>
#
# </div>
# <div>Model Deployment
#
# <li>
#     <a href="Machine_Learning_and_Data-Science_by_Jose_Portilla/./24-Model-Deployment/00-Model-Persistence.html" target = 'blank' class = 'links'>Model Persistence</a>
# </li>
#
# <li>
#     <a href="Machine_Learning_and_Data-Science_by_Jose_Portilla/./24-Model-Deployment/01-Serving-Model-as-API.html" target = 'blank' class = 'links'>Serving Model as API</a>
# </li>
#
# </div>
